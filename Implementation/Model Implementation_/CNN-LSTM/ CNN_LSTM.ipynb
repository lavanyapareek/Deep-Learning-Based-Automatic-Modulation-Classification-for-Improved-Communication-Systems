# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from keras.layers import Activation, Dense
from keras.models import Model
from keras.layers import Layer
import keras.backend as K
import keras

# %% [markdown]
# Using Keras 1.2, And tensor Flow 1.x

# %%
from keras import models
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Input
from keras.layers import Dropout
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, Reshape, ZeroPadding2D

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#De-Pickling Data with encoding latin1
with open("/content/drive/MyDrive/Colab Notebooks/DATA/Aditya/RML2016.10a_dict.pickle.pkl", 'rb') as f:
    Xd = pickle.load(f, encoding='latin1')

# %%
classes = ['32PSK', '16APSK', '32QAM', 'FM', 'GMSK', '32APSK', 'OQPSK', #1
 '8ASK', 'BPSK','8PSK', 'AM-SSB-SC', '4ASK', '16PSK', '64APSK', '128QAM', '128APSK','AM-DSB-SC', #2 
'AM-SSB-WC', '64QAM', 'QPSK', '256QAM','AM-DSB-WC','OOK','16QAM']

# %%
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
X = []
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod,snr)])
        for i in range(Xd[(mod,snr)].shape[0]):  lbl.append((mod,snr))
X = np.vstack(X)

# %%
np.random.seed(2016)  
n_examples = X.shape[0]
n_train = n_examples * 0.5  # 对半
train_idx = np.random.choice(range(0, n_examples), size=int(n_train), replace=False)
test_idx = list(set(range(0, n_examples)) - set(train_idx))  # label
X_train = X[train_idx]
X_test = X[test_idx]

# %%
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy) + 1])
    yy1[np.arange(len(yy)), yy] = 1
    return yy1

# %%
trainy = list(map(lambda x: mods.index(lbl[x][0]), train_idx))
Y_train = to_onehot(trainy)
Y_test = to_onehot(list(map(lambda x: mods.index(lbl[x][0]), test_idx)))

# %%
in_shp = list(X_train.shape[1:])
print(X_train.shape, in_shp)
classes = mods
# Out:
# (110000, 2, 128) [2, 128]

# %%
dr = 0.5  # dropout rate l

# Reshape [N,2,128] to [N,1,2,128] on input
input_x = Input(shape=(1, 2, 128))

# %%
class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras import layers

# %%
model = Sequential()
model = models.Sequential()
model.add(Reshape(in_shp+[1], input_shape=in_shp))
model.add(ZeroPadding2D((0,2)))

model.add(Conv2D(256, (1, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform', input_shape=(2, 128, 1)))
model.add(MaxPooling2D(pool_size=(1, 2), padding='valid',  data_format=None))
model.add(layers.Dropout(0.3))

model.add(Conv2D(256, (2, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(1, 2), padding='valid',  data_format=None))
model.add(layers.Dropout(0.3))
model.add(Conv2D(80, (1, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(1, 2), padding='valid',  data_format=None))
model.add(layers.Dropout(0.3))

model.add(Conv2D(80, (1, 3), activation='relu', padding='same', kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(1, 2), padding='valid',  data_format=None))
model.add(layers.Dropout(0.3))

model.add(Reshape((2, 640)))

model.add(LSTM(50, activation='relu'))
model.add(layers.Dropout(0.3))

model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
model.add(layers.Dropout(0.3))

model.add(Dense(11, activation='softmax', kernel_initializer='he_normal'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_10 (Reshape)         (None, 2, 128, 1)         0
# _________________________________________________________________
# zero_padding2d_14 (ZeroPaddi (None, 2, 132, 1)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 2, 132, 256)       1024
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 2, 66, 256)        0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 2, 66, 256)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 66, 256)        393472
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 2, 33, 256)        0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 2, 33, 256)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 33, 80)         61520
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 2, 16, 80)         0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 2, 16, 80)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 2, 16, 80)         19280
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 2, 8, 80)          0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 2, 8, 80)          0
# _________________________________________________________________
# reshape_11 (Reshape)         (None, 2, 640)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 50)                138200
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               6528
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 11)                1419
# =================================================================
# Total params: 621,443
# Trainable params: 621,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# End of building, we will start fitting the neural network
# Set up some params
epochs = 150  # number of epochs to train on
batch_size = 1024  # training batch size default1024
filepath = "convmodrecnets_%s_0.5.wts.h5" % ('CNN_LSTM')

# %%
history = model.fit(X_train,
                    Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(X_test, Y_test))
# Out:
# Epoch 1/150
# 108/108 [==============================] - 26s 226ms/step - loss: 2.3859 - accuracy: 0.0968 - val_loss: 2.2226 - val_accuracy: 0.1619
# Epoch 2/150
# 108/108 [==============================] - 23s 212ms/step - loss: 2.1372 - accuracy: 0.1905 - val_loss: 1.8115 - val_accuracy: 0.3232
# Epoch 3/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.7961 - accuracy: 0.3145 - val_loss: 1.5985 - val_accuracy: 0.3844
# Epoch 4/150
# 108/108 [==============================] - 23s 214ms/step - loss: 1.6265 - accuracy: 0.3707 - val_loss: 1.4870 - val_accuracy: 0.4204
# Epoch 5/150
# 108/108 [==============================] - 24s 221ms/step - loss: 1.5279 - accuracy: 0.4064 - val_loss: 1.4585 - val_accuracy: 0.4405
# Epoch 6/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.4666 - accuracy: 0.4314 - val_loss: 1.3897 - val_accuracy: 0.4615
# Epoch 7/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.4363 - accuracy: 0.4419 - val_loss: 1.3241 - val_accuracy: 0.4846
# Epoch 8/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.3948 - accuracy: 0.4590 - val_loss: 1.3103 - val_accuracy: 0.4894
# Epoch 9/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.3774 - accuracy: 0.4655 - val_loss: 1.2982 - val_accuracy: 0.4936
# Epoch 10/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3611 - accuracy: 0.4713 - val_loss: 1.3336 - val_accuracy: 0.4743
# Epoch 11/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3498 - accuracy: 0.4750 - val_loss: 1.3297 - val_accuracy: 0.4824
# Epoch 12/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3347 - accuracy: 0.4808 - val_loss: 1.2850 - val_accuracy: 0.4910
# Epoch 13/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3290 - accuracy: 0.4804 - val_loss: 1.2785 - val_accuracy: 0.5064
# Epoch 14/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3167 - accuracy: 0.4904 - val_loss: 1.2766 - val_accuracy: 0.4935
# Epoch 15/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3067 - accuracy: 0.4899 - val_loss: 1.2486 - val_accuracy: 0.5175
# Epoch 16/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.3023 - accuracy: 0.4946 - val_loss: 1.2511 - val_accuracy: 0.5157
# Epoch 17/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2871 - accuracy: 0.4975 - val_loss: 1.2624 - val_accuracy: 0.5053
# Epoch 18/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2827 - accuracy: 0.5019 - val_loss: 1.2805 - val_accuracy: 0.4950
# Epoch 19/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2813 - accuracy: 0.5023 - val_loss: 1.2504 - val_accuracy: 0.5076
# Epoch 20/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2795 - accuracy: 0.5032 - val_loss: 1.2245 - val_accuracy: 0.5232
# Epoch 21/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2721 - accuracy: 0.5048 - val_loss: 1.2305 - val_accuracy: 0.5209
# Epoch 22/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2620 - accuracy: 0.5100 - val_loss: 1.2288 - val_accuracy: 0.5232
# Epoch 23/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2569 - accuracy: 0.5105 - val_loss: 1.2201 - val_accuracy: 0.5269
# Epoch 24/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2584 - accuracy: 0.5112 - val_loss: 1.2281 - val_accuracy: 0.5225
# Epoch 25/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2542 - accuracy: 0.5106 - val_loss: 1.2097 - val_accuracy: 0.5154
# Epoch 26/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2538 - accuracy: 0.5127 - val_loss: 1.2253 - val_accuracy: 0.5173
# Epoch 27/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2451 - accuracy: 0.5174 - val_loss: 1.2258 - val_accuracy: 0.5180
# Epoch 28/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2323 - accuracy: 0.5199 - val_loss: 1.2191 - val_accuracy: 0.5197
# Epoch 29/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2402 - accuracy: 0.5154 - val_loss: 1.2380 - val_accuracy: 0.5201
# Epoch 30/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2417 - accuracy: 0.5169 - val_loss: 1.2022 - val_accuracy: 0.5377
# Epoch 31/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2264 - accuracy: 0.5223 - val_loss: 1.2118 - val_accuracy: 0.5280
# Epoch 32/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2315 - accuracy: 0.5217 - val_loss: 1.2174 - val_accuracy: 0.5350
# Epoch 33/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2269 - accuracy: 0.5236 - val_loss: 1.2053 - val_accuracy: 0.5340
# Epoch 34/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2246 - accuracy: 0.5259 - val_loss: 1.2257 - val_accuracy: 0.5275
# Epoch 35/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2246 - accuracy: 0.5292 - val_loss: 1.1974 - val_accuracy: 0.5399
# Epoch 36/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.2208 - accuracy: 0.5260 - val_loss: 1.2027 - val_accuracy: 0.5376
# Epoch 37/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2138 - accuracy: 0.5288 - val_loss: 1.2029 - val_accuracy: 0.5362
# Epoch 38/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.2140 - accuracy: 0.5326 - val_loss: 1.1919 - val_accuracy: 0.5339
# Epoch 39/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2149 - accuracy: 0.5306 - val_loss: 1.2099 - val_accuracy: 0.5262
# Epoch 40/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2075 - accuracy: 0.5336 - val_loss: 1.1916 - val_accuracy: 0.5419
# Epoch 41/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2050 - accuracy: 0.5358 - val_loss: 1.1782 - val_accuracy: 0.5479
# Epoch 42/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2103 - accuracy: 0.5342 - val_loss: 1.1803 - val_accuracy: 0.5367
# Epoch 43/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1971 - accuracy: 0.5379 - val_loss: 1.1822 - val_accuracy: 0.5384
# Epoch 44/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2116 - accuracy: 0.5350 - val_loss: 1.1780 - val_accuracy: 0.5461
# Epoch 45/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2047 - accuracy: 0.5342 - val_loss: 1.1901 - val_accuracy: 0.5338
# Epoch 46/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1985 - accuracy: 0.5381 - val_loss: 1.1767 - val_accuracy: 0.5373
# Epoch 47/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.2004 - accuracy: 0.5359 - val_loss: 1.1838 - val_accuracy: 0.5353
# Epoch 48/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1906 - accuracy: 0.5418 - val_loss: 1.1729 - val_accuracy: 0.5482
# Epoch 49/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1951 - accuracy: 0.5384 - val_loss: 1.1909 - val_accuracy: 0.5414
# Epoch 50/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1912 - accuracy: 0.5426 - val_loss: 1.1717 - val_accuracy: 0.5504
# Epoch 51/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1918 - accuracy: 0.5402 - val_loss: 1.1858 - val_accuracy: 0.5349
# Epoch 52/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1837 - accuracy: 0.5436 - val_loss: 1.1860 - val_accuracy: 0.5445
# Epoch 53/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1908 - accuracy: 0.5400 - val_loss: 1.1791 - val_accuracy: 0.5460
# Epoch 54/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1900 - accuracy: 0.5416 - val_loss: 1.1767 - val_accuracy: 0.5435
# Epoch 55/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1865 - accuracy: 0.5432 - val_loss: 1.1891 - val_accuracy: 0.5339
# Epoch 56/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1817 - accuracy: 0.5423 - val_loss: 1.1688 - val_accuracy: 0.5434
# Epoch 57/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1780 - accuracy: 0.5457 - val_loss: 1.1760 - val_accuracy: 0.5449
# Epoch 58/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1846 - accuracy: 0.5438 - val_loss: 1.1926 - val_accuracy: 0.5411
# Epoch 59/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1849 - accuracy: 0.5444 - val_loss: 1.1941 - val_accuracy: 0.5335
# Epoch 60/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1828 - accuracy: 0.5463 - val_loss: 1.1663 - val_accuracy: 0.5467
# Epoch 61/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1795 - accuracy: 0.5445 - val_loss: 1.1833 - val_accuracy: 0.5384
# Epoch 62/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1785 - accuracy: 0.5473 - val_loss: 1.1888 - val_accuracy: 0.5426
# Epoch 63/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1725 - accuracy: 0.5473 - val_loss: 1.1662 - val_accuracy: 0.5508
# Epoch 64/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1729 - accuracy: 0.5474 - val_loss: 1.1844 - val_accuracy: 0.5428
# Epoch 65/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1755 - accuracy: 0.5484 - val_loss: 1.1747 - val_accuracy: 0.5411
# Epoch 66/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1674 - accuracy: 0.5492 - val_loss: 1.1822 - val_accuracy: 0.5419
# Epoch 67/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1661 - accuracy: 0.5484 - val_loss: 1.1625 - val_accuracy: 0.5529
# Epoch 68/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1725 - accuracy: 0.5487 - val_loss: 1.1851 - val_accuracy: 0.5443
# Epoch 69/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1713 - accuracy: 0.5485 - val_loss: 1.1707 - val_accuracy: 0.5467
# Epoch 70/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1715 - accuracy: 0.5469 - val_loss: 1.1679 - val_accuracy: 0.5490
# Epoch 71/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1673 - accuracy: 0.5515 - val_loss: 1.1728 - val_accuracy: 0.5485
# Epoch 72/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1739 - accuracy: 0.5488 - val_loss: 1.1750 - val_accuracy: 0.5417
# Epoch 73/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1682 - accuracy: 0.5495 - val_loss: 1.1908 - val_accuracy: 0.5369
# Epoch 74/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1665 - accuracy: 0.5505 - val_loss: 1.1668 - val_accuracy: 0.5534
# Epoch 75/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1671 - accuracy: 0.5525 - val_loss: 1.1692 - val_accuracy: 0.5466
# Epoch 76/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1726 - accuracy: 0.5484 - val_loss: 1.1521 - val_accuracy: 0.5569
# Epoch 77/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1645 - accuracy: 0.5494 - val_loss: 1.1630 - val_accuracy: 0.5508
# Epoch 78/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1553 - accuracy: 0.5555 - val_loss: 1.1605 - val_accuracy: 0.5530
# Epoch 79/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1632 - accuracy: 0.5532 - val_loss: 1.1603 - val_accuracy: 0.5543
# Epoch 80/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1651 - accuracy: 0.5508 - val_loss: 1.1601 - val_accuracy: 0.5473
# Epoch 81/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1601 - accuracy: 0.5513 - val_loss: 1.1731 - val_accuracy: 0.5497
# Epoch 82/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1568 - accuracy: 0.5559 - val_loss: 1.1489 - val_accuracy: 0.5526
# Epoch 83/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1592 - accuracy: 0.5514 - val_loss: 1.1637 - val_accuracy: 0.5475
# Epoch 84/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1545 - accuracy: 0.5555 - val_loss: 1.1574 - val_accuracy: 0.5559
# Epoch 85/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1574 - accuracy: 0.5532 - val_loss: 1.1705 - val_accuracy: 0.5442
# Epoch 86/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1558 - accuracy: 0.5564 - val_loss: 1.1559 - val_accuracy: 0.5539
# Epoch 87/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1567 - accuracy: 0.5537 - val_loss: 1.1589 - val_accuracy: 0.5559
# Epoch 88/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1511 - accuracy: 0.5558 - val_loss: 1.1598 - val_accuracy: 0.5553
# Epoch 89/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1483 - accuracy: 0.5574 - val_loss: 1.1625 - val_accuracy: 0.5542
# Epoch 90/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1566 - accuracy: 0.5528 - val_loss: 1.1611 - val_accuracy: 0.5545
# Epoch 91/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1504 - accuracy: 0.5564 - val_loss: 1.1598 - val_accuracy: 0.5544
# Epoch 92/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1540 - accuracy: 0.5575 - val_loss: 1.1494 - val_accuracy: 0.5582
# Epoch 93/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1466 - accuracy: 0.5590 - val_loss: 1.1604 - val_accuracy: 0.5545
# Epoch 94/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1474 - accuracy: 0.5553 - val_loss: 1.1555 - val_accuracy: 0.5476
# Epoch 95/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1466 - accuracy: 0.5567 - val_loss: 1.1580 - val_accuracy: 0.5482
# Epoch 96/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1477 - accuracy: 0.5591 - val_loss: 1.1641 - val_accuracy: 0.5535
# Epoch 97/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1517 - accuracy: 0.5580 - val_loss: 1.1510 - val_accuracy: 0.5576
# Epoch 98/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1483 - accuracy: 0.5563 - val_loss: 1.1486 - val_accuracy: 0.5529
# Epoch 99/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1422 - accuracy: 0.5615 - val_loss: 1.1403 - val_accuracy: 0.5580
# Epoch 100/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1438 - accuracy: 0.5611 - val_loss: 1.1433 - val_accuracy: 0.5634
# Epoch 101/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1488 - accuracy: 0.5597 - val_loss: 1.1545 - val_accuracy: 0.5573
# Epoch 102/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1403 - accuracy: 0.5619 - val_loss: 1.1489 - val_accuracy: 0.5574
# Epoch 103/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1452 - accuracy: 0.5587 - val_loss: 1.1493 - val_accuracy: 0.5530
# Epoch 104/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1424 - accuracy: 0.5615 - val_loss: 1.1498 - val_accuracy: 0.5604
# Epoch 105/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1417 - accuracy: 0.5601 - val_loss: 1.1407 - val_accuracy: 0.5614
# Epoch 106/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1417 - accuracy: 0.5627 - val_loss: 1.1527 - val_accuracy: 0.5533
# Epoch 107/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1371 - accuracy: 0.5626 - val_loss: 1.1326 - val_accuracy: 0.5611
# Epoch 108/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1400 - accuracy: 0.5630 - val_loss: 1.1409 - val_accuracy: 0.5623
# Epoch 109/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1349 - accuracy: 0.5631 - val_loss: 1.1453 - val_accuracy: 0.5608
# Epoch 110/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1391 - accuracy: 0.5645 - val_loss: 1.1548 - val_accuracy: 0.5568
# Epoch 111/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1399 - accuracy: 0.5630 - val_loss: 1.1546 - val_accuracy: 0.5502
# Epoch 112/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1385 - accuracy: 0.5632 - val_loss: 1.1534 - val_accuracy: 0.5571
# Epoch 113/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1333 - accuracy: 0.5627 - val_loss: 1.1517 - val_accuracy: 0.5539
# Epoch 114/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1325 - accuracy: 0.5631 - val_loss: 1.1641 - val_accuracy: 0.5508
# Epoch 115/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1365 - accuracy: 0.5629 - val_loss: 1.1404 - val_accuracy: 0.5625
# Epoch 116/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1334 - accuracy: 0.5658 - val_loss: 1.1590 - val_accuracy: 0.5491
# Epoch 117/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1378 - accuracy: 0.5632 - val_loss: 1.1450 - val_accuracy: 0.5572
# Epoch 118/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1311 - accuracy: 0.5662 - val_loss: 1.1363 - val_accuracy: 0.5598
# Epoch 119/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1324 - accuracy: 0.5654 - val_loss: 1.1547 - val_accuracy: 0.5512
# Epoch 120/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1343 - accuracy: 0.5632 - val_loss: 1.1384 - val_accuracy: 0.5597
# Epoch 121/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1357 - accuracy: 0.5621 - val_loss: 1.1397 - val_accuracy: 0.5631
# Epoch 122/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1315 - accuracy: 0.5651 - val_loss: 1.1434 - val_accuracy: 0.5555
# Epoch 123/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1320 - accuracy: 0.5635 - val_loss: 1.1460 - val_accuracy: 0.5611
# Epoch 124/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1269 - accuracy: 0.5663 - val_loss: 1.1427 - val_accuracy: 0.5633
# Epoch 125/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1221 - accuracy: 0.5705 - val_loss: 1.1273 - val_accuracy: 0.5661
# Epoch 126/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1332 - accuracy: 0.5636 - val_loss: 1.1441 - val_accuracy: 0.5606
# Epoch 127/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1249 - accuracy: 0.5642 - val_loss: 1.1292 - val_accuracy: 0.5659
# Epoch 128/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1304 - accuracy: 0.5652 - val_loss: 1.1546 - val_accuracy: 0.5580
# Epoch 129/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1290 - accuracy: 0.5669 - val_loss: 1.1506 - val_accuracy: 0.5599
# Epoch 130/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1199 - accuracy: 0.5687 - val_loss: 1.1346 - val_accuracy: 0.5646
# Epoch 131/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1233 - accuracy: 0.5710 - val_loss: 1.1392 - val_accuracy: 0.5650
# Epoch 132/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1228 - accuracy: 0.5661 - val_loss: 1.1244 - val_accuracy: 0.5681
# Epoch 133/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1297 - accuracy: 0.5661 - val_loss: 1.1399 - val_accuracy: 0.5620
# Epoch 134/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1249 - accuracy: 0.5674 - val_loss: 1.1225 - val_accuracy: 0.5692
# Epoch 135/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1252 - accuracy: 0.5694 - val_loss: 1.1330 - val_accuracy: 0.5635
# Epoch 136/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1207 - accuracy: 0.5698 - val_loss: 1.1398 - val_accuracy: 0.5639
# Epoch 137/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1200 - accuracy: 0.5712 - val_loss: 1.1373 - val_accuracy: 0.5651
# Epoch 138/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1235 - accuracy: 0.5672 - val_loss: 1.1344 - val_accuracy: 0.5647
# Epoch 139/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1138 - accuracy: 0.5724 - val_loss: 1.1296 - val_accuracy: 0.5637
# Epoch 140/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1184 - accuracy: 0.5700 - val_loss: 1.1351 - val_accuracy: 0.5613
# Epoch 141/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1221 - accuracy: 0.5676 - val_loss: 1.1270 - val_accuracy: 0.5677
# Epoch 142/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1167 - accuracy: 0.5711 - val_loss: 1.1355 - val_accuracy: 0.5655
# Epoch 143/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1171 - accuracy: 0.5722 - val_loss: 1.1266 - val_accuracy: 0.5684
# Epoch 144/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1248 - accuracy: 0.5674 - val_loss: 1.1206 - val_accuracy: 0.5680
# Epoch 145/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1152 - accuracy: 0.5700 - val_loss: 1.1298 - val_accuracy: 0.5610
# Epoch 146/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1231 - accuracy: 0.5701 - val_loss: 1.1358 - val_accuracy: 0.5658
# Epoch 147/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1153 - accuracy: 0.5726 - val_loss: 1.1293 - val_accuracy: 0.5681
# Epoch 148/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1220 - accuracy: 0.5715 - val_loss: 1.1239 - val_accuracy: 0.5700
# Epoch 149/150
# 108/108 [==============================] - 23s 210ms/step - loss: 1.1161 - accuracy: 0.5687 - val_loss: 1.1298 - val_accuracy: 0.5660
# Epoch 150/150
# 108/108 [==============================] - 23s 211ms/step - loss: 1.1182 - accuracy: 0.5710 - val_loss: 1.1317 - val_accuracy: 0.5678

# %%
# Show loss curves
plt.figure()
plt.title('Training performance')
plt.plot(history.epoch, history.history['loss'], label='train loss+error')
plt.plot(history.epoch, history.history['val_loss'], label='val_error')
plt.legend()

# %%
acc = {}
for snr in snrs:
  # extract classes @ SNR
  test_SNRs = list(map(lambda x: lbl[x][1], test_idx))
  test_X_i = X_test[np.where(np.array(test_SNRs)==snr)]
  test_Y_i = Y_test[np.where(np.array(test_SNRs)==snr)]
  # estimate classes
  test_Y_i_hat = model.predict(test_X_i)
  conf = np.zeros([len(classes),len(classes)])
  confnorm = np.zeros([len(classes),len(classes)])
  for i in range(0,test_X_i.shape[0]):
    j = list(test_Y_i[i,:]).index(1)
    k = int(np.argmax(test_Y_i_hat[i,:]))
    conf[j,k] = conf[j,k] + 1

  for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])

  #plt.figure()
  #plot_confusion_matrix(confnorm, labels=classes, title="ConvNet Confusion Matrix (SNR=%d)"%(snr))
  cor = np.sum(np.diag(conf))
  ncor = np.sum(conf) - cor
  print("SNR: ",snr, " Overall Accuracy: ", cor / (cor + ncor))
  acc[snr] = 1.0 * cor / (cor + ncor)
# Out:
# SNR:  -20  Overall Accuracy:  0.09460201280878316
# SNR:  -18  Overall Accuracy:  0.09227974568574024
# SNR:  -16  Overall Accuracy:  0.09352387843704775
# SNR:  -14  Overall Accuracy:  0.09202453987730061
# SNR:  -12  Overall Accuracy:  0.11485870556061988
# SNR:  -10  Overall Accuracy:  0.17611515905455838
# SNR:  -8  Overall Accuracy:  0.3560536468859085
# SNR:  -6  Overall Accuracy:  0.5707478005865103
# SNR:  -4  Overall Accuracy:  0.6916820702402957
# SNR:  -2  Overall Accuracy:  0.7659651669085631
# SNR:  0  Overall Accuracy:  0.8091240875912409
# SNR:  2  Overall Accuracy:  0.8235187204652854
# SNR:  4  Overall Accuracy:  0.8324155653450808
# SNR:  6  Overall Accuracy:  0.8359205776173285
# SNR:  8  Overall Accuracy:  0.8382326420198377
# SNR:  10  Overall Accuracy:  0.8446265938069216
# SNR:  12  Overall Accuracy:  0.8308890095962339
# SNR:  14  Overall Accuracy:  0.8361321276988374
# SNR:  16  Overall Accuracy:  0.8318552036199095
# SNR:  18  Overall Accuracy:  0.8356435643564356

# %%
print(acc)
fd = open('results_cnn_d0.5.dat','wb')
pickle.dump( ("CNN", 0.5, acc) , fd )

# Plot accuracy curve
plt.plot(snrs, list(map(lambda x: acc[x], snrs)))
plt.xlabel("Signal to Noise Ratio")
plt.ylabel("Classification Accuracy")
plt.title("New Model Classification Accuracy on RadioML 2016.10 Alpha")
plt.show()
# Out:
# {-20: 0.09460201280878316, -18: 0.09227974568574024, -16: 0.09352387843704775, -14: 0.09202453987730061, -12: 0.11485870556061988, -10: 0.17611515905455838, -8: 0.3560536468859085, -6: 0.5707478005865103, -4: 0.6916820702402957, -2: 0.7659651669085631, 0: 0.8091240875912409, 2: 0.8235187204652854, 4: 0.8324155653450808, 6: 0.8359205776173285, 8: 0.8382326420198377, 10: 0.8446265938069216, 12: 0.8308890095962339, 14: 0.8361321276988374, 16: 0.8318552036199095, 18: 0.8356435643564356}

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()


test_Y_hat = model.predict(X_test, batch_size=batch_size)
conf = np.zeros([len(classes),len(classes)])
confnorm = np.zeros([len(classes),len(classes)])
for i in range(0,X_test.shape[0]):
    j = list(Y_test[i,:]).index(1)
    k = int(np.argmax(test_Y_hat[i,:]))
    conf[j,k] = conf[j,k] + 1
for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])

plt.figure(num=None, figsize=(7, 7), dpi=80, facecolor='w', edgecolor='black')
plot_confusion_matrix(confnorm, labels=classes)
